# %%
import urllib.request as req
import pandas as pd
#  scratch cryptopro HTML
url = "https://cryptopro.app/"
#  Build request object with headers
request=req.Request(url, headers={
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.190 Safari/537.36"
})
with req.urlopen(request) as response:
    data = response.read().decode("utf-8")
import bs4
root=bs4.BeautifulSoup(data, "html.parser")
#  find div stable as class_="id"
names=root.find_all("td", class_="nm")
prices=root.find_all("td", class_="pr")
chs=root.find_all('td', class_='ch')
nameArr = []
priceArr = []
chArr = []
for name in names:
    #  print(name.a.string)
    nameArr.append(name.a.string)
for price in prices:
    priceArr.append(price.string)
for ch in chs:
    chArr.append(ch.string)
# Set crypto name as data name
df = pd.DataFrame(nameArr, columns = ["Name"])
df = pd.concat([df, pd.DataFrame(priceArr,columns=['Price'])],axis=1)
df = pd.concat([df, pd.DataFrame(chArr,columns=['Change'])],axis=1)
df.index = df.index + 1
pd.set_option('display.max_rows', None)
print(df)
# Out:
#                                 Name        Price   Change
# 1                            Bitcoin   $50,968.80   +6.93%
# 2                           Ethereum    $1,668.51   +7.67%
# 3                       Binance Coin      $237.18   +6.63%
# 4                             Tether        $1.00   -0.04%
# 5                            Cardano        $1.13   +1.44%
# 6                           Polkadot       $34.73   +5.10%
# 7                                XRP    $0.466412   +2.02%
# 8                            Uniswap       $32.18  +14.70%
# 9                           Litecoin      $186.66   +4.77%
# 10                         Chainlink       $28.15   +3.99%
# 11                      Bitcoin Cash      $513.51   +5.21%
# 12                           Stellar    $0.414436   +4.84%
# 13                          USD Coin        $1.00   -0.02%
# 14                          Dogecoin   $0.0515391   +2.39%
# 15                               NEM    $0.725983   -2.70%
# 16                   Wrapped Bitcoin   $50,848.50   +6.73%
# 17                              Aave      $414.50  +13.06%
# 18                             THETA        $4.31  +10.26%
# 19                            Cosmos       $19.30   +4.11%
# 20                   Crypto.com Coin    $0.158152   +4.75%
# 21                            Monero      $209.09   +3.38%
# 22                              TRON   $0.0511712   +3.05%
# 23                           VeChain   $0.0570687  +10.88%
# 24                              IOTA        $1.30   +0.29%
# 25                               EOS        $3.80   +4.16%
# 26                            Solana       $13.76  +11.16%
# 27                        Bitcoin SV      $184.74   +2.89%
# 28                             Terra        $7.98   -4.86%
# 29                             Tezos        $3.95   +3.42%
# 30                       Binance USD           $1   -0.18%
# 31                       Huobi Token       $15.12   +1.72%
# 32                               Neo       $39.12   +4.55%
# 33                          Algorand        $1.12   +9.10%
# 34                         FTX Token       $30.47   +6.55%
# 35                               Dai           $1   -0.05%
# 36                         Synthetix       $21.27   +3.60%
# 37                            Elrond      $145.00   +5.00%
# 38                              cDAI   $0.0211515   -0.59%
# 39                          Filecoin       $41.29   +3.34%
# 40                         The Graph        $1.92   +7.67%
# 41                              cETH       $33.34   +5.31%
# 42                         Avalanche       $27.35  +11.11%
# 43                             Maker    $2,205.48   +0.22%
# 44                             Sushi       $17.11   +4.63%
# 45                              Dash      $212.38   +3.83%
# 46                          Compound      $490.72   -1.24%
# 47                            Decred      $153.58   +3.57%
# 48                            Kusama      $235.78   +7.35%
# 49                             cUSDC   $0.0216541   -0.56%
# 50                      UNUS SED LEO        $1.94   +1.80%
# 51                             Zcash      $127.35   +5.71%
# 52                     Voyager Token        $6.29  +14.89%
# 53                       PancakeSwap       $11.71   +6.29%
# 54                  Ethereum Classic       $11.54   +6.71%
# 55                         Ravencoin    $0.159005   +5.08%
# 56                           Zilliqa    $0.118142   +4.48%
# 57                              Near        $4.38   +8.08%
# 58                      Bitcoin BEP2   $50,604.20   +5.79%
# 59                            Bancor        $8.28   +7.46%
# 60                         THORChain        $5.71   +2.97%
# 61                        BitTorrent  $0.00124503   +2.29%
# 62                         Huobi BTC   $50,703.00   +5.45%
# 63                              Nexo        $2.14   +6.43%
# 64                     yearn.finance   $36,188.00  +11.12%
# 65                            Fantom    $0.452067   +3.18%
# 66                              ICON        $1.91   +8.63%
# 67                            Stacks        $1.16   +2.29%
# 68                               UMA       $21.74   +2.83%
# 69                           Celsius        $4.69   +3.93%
# 70                        Enjin Coin        $1.32  +18.94%
# 71                               Ren        $1.10   +5.24%
# 72                         SwissBorg        $1.16   -0.94%
# 73                  Hedera Hashgraph    $0.151834   +5.03%
# 74                           Polygon    $0.216308   +2.22%
# 75                                0x        $1.40   +4.87%
# 76             Basic Attention Token    $0.713244   +9.15%
# 77                             Waves       $10.10   +2.04%
# 78                            Revain   $0.0123272   -0.05%
# 79                              Flow       $35.08   +2.19%
# 80                               OKB       $17.20   +2.90%
# 81                          Ontology        $1.04   +1.11%
# 82                          DigiByte   $0.0550781   +3.06%
# 83                        Theta Fuel    $0.143351   +3.14%
# 84                            renBTC   $50,773.00   +6.46%
# 85                              IOST    $0.045336   +0.22%
# 86                            xSUSHI       $19.12   +3.59%
# 87                               Amp   $0.0220394   +1.85%
# 88                          Loopring    $0.578368   +2.72%
# 89                          TerraUSD        $1.01   +0.27%
# 90                       OMG Network        $5.02   +7.97%
# 91                              Nano        $5.23   +2.89%
# 92                    Paxos Standard        $1.00   -0.17%
# 93                            Chiliz    $0.135019  +31.86%
# 94                    Ocean Protocol        $1.58  +44.43%
# 95                    Reserve Rights   $0.0684535  +16.66%
# 96                      Decentraland    $0.399586  +14.73%
# 97                              HUSD           $1   +0.11%
# 98                              Qtum        $6.29   +2.80%
# 99                            ZKSwap        $3.04   -3.94%
# 100                          Arweave       $13.44   -0.84%
# 101                          Horizen       $48.09  +14.65%
# 102                             Mdex        $4.73   +0.30%
# 103                            1inch        $3.97   +6.80%
# 104                             Holo  $0.00307566   +0.80%
# 105                          Siacoin    $0.010853   +3.67%
# 106                     Bitcoin Gold       $29.21   +7.03%
# 107                          Pundi X  $0.00204523   +1.86%
# 108                  Curve DAO Token        $2.24  +12.49%
# 109                 Energy Web Token       $15.89   +9.19%
# 110                            Quant       $35.60  +11.89%
# 111                            Golem    $0.420792   +4.60%
# 112                    Kyber Network        $2.04   +0.76%
# 113                             Lisk        $3.19   +3.35%
# 114                         Balancer       $42.66  +11.21%
# 115                       HedgeTrade        $1.10   +0.64%
# 116                     KuCoin Token        $4.67  +10.39%
# 117                          Harmony   $0.0381062   -4.32%
# 118                     Nexus Mutual       $63.50   +4.22%
# 119                     Reef Finance   $0.0390017   +1.46%
# 120                            Verge   $0.0215673   +3.26%
# 121                    Alpha Finance        $1.67   -1.50%
# 122                            Augur       $29.46   +2.60%
# 123                             DODO        $4.21   +7.02%
# 124                           Status   $0.0884808   +6.08%
# 125                             Celo        $3.90   +1.25%
# 126                       Ampleforth        $1.03   -2.73%
# 127                          TrueUSD        $1.00   -0.05%
# 128                            Venus       $39.82   +2.45%
# 129                   Orion Protocol       $16.69   +2.11%
# 130                         Fetch.ai    $0.363112   +2.79%
# 131                            cUSDT   $0.0209878   +0.06%
# 132                       Badger DAO       $47.33   +1.88%
# 133                            Civic    $0.399224   +5.79%
# 134                            IoTeX   $0.0273162   +2.70%
# 135                            Serum        $6.13  +26.08%
# 136                           Helium        $4.20   +4.47%
# 137                 Bitcoin Cash ABC       $16.19   +8.64%
# 138                         Populous        $4.75  +58.21%
# 139                         Polymath    $0.423309   +4.83%
# 140                    Band Protocol       $13.23   +6.93%
# 141                Lido Staked Ether    $1,598.56   +7.44%
# 142                   Nervos Network   $0.0108758   +0.88%
# 143                             Ankr   $0.0353585  +10.05%
# 144                  Mirror Protocol        $6.40  +16.38%
# 145                        TomoChain        $2.71  +43.73%
# 146                        GateToken        $1.48   +2.57%
# 147                     MaidSafeCoin    $0.477616   +5.00%
# 148                          FunFair   $0.0323614   +8.25%
# 149                           Gnosis      $137.92   +5.38%
# 150                             SAND    $0.375733  +12.90%
# 151     RSK Infrastructure Framework    $0.292563   +9.12%
# 152                        Trustswap        $3.94   +7.99%
# 153                             cUNI    $0.647729  +14.81%
# 154                           Aragon        $5.11   +3.56%
# 155                            Ardor    $0.201447   +0.41%
# 156                     Polkastarter        $4.21   -0.33%
# 157                             COTI    $0.296731  +22.84%
# 158                         NuCypher    $0.684838   +2.17%
# 159                     VeThor Token  $0.00602723  +11.41%
# 160                          Stratis        $1.55   +5.18%
# 161                          Kava.io        $4.08   +9.37%
# 162                  Bitcoin Diamond        $1.05   +4.53%
# 163                            Swipe        $2.66  +13.98%
# 164                        Numeraire       $40.05   +2.76%
# 165                      LUKSO Token       $15.02   -2.96%
# 166                             Gala   $0.0299106   -8.00%
# 167                           Utrust    $0.419061  +24.73%
# 168                         ZB Token    $0.409358   +2.36%
# 169                              WAX    $0.123716  +10.49%
# 170                           Komodo        $1.50   -0.42%
# 171  Bitcoin Standard Hashrate Token      $313.48   +2.98%
# 172                          SafePal        $1.96   +4.23%
# 173                    Akash Network        $5.46   +3.53%
# 174                              Ark        $1.40   -2.19%
# 175                        Unibright        $1.19   +3.67%
# 176                           Secret        $2.90   +3.34%
# 177                            Storj     $0.68954   +2.81%
# 178                          Telcoin  $0.00351041   +8.57%
# 179                            Steem    $0.462287   +6.09%
# 180                      OriginTrail    $0.500277  +20.64%
# 181                             sETH    $1,679.58   +5.80%
# 182                   SingularityNET    $0.195258   +8.12%
# 183                        BitShares   $0.0562679   +9.54%
# 184                        ABBC Coin    $0.201718   +2.51%
# 185                            Ultra    $0.354532   +6.61%
# 186                     Hifi Finance   $0.0159048   +8.92%
# 187                       district0x    $0.264571   +2.83%
# 188                             Sora      $552.90   +8.65%
# 189                             aelf    $0.288357   +4.02%
# 190                             BORA    $0.182701   +1.55%
# 191                             MATH        $1.52   -0.13%
# 192                             Dent  $0.00167508   +0.71%
# 193                  saffron.finance    $2,315.72   -2.65%
# 194                         Wanchain    $0.896237  +10.20%
# 195                    Celer Network   $0.0281512   -2.51%
# 196      BTC Standard Hashrate Token      $315.18   +3.04%
# 197                        iExec RLC        $1.83  +11.09%
# 198                    Oasis Network    $0.122073   +5.21%
# 199                     Power Ledger    $0.328076  +10.22%
# 200               Trust Wallet Token    $0.529532   +7.00%
# 201                      RedFOX Labs    $0.140192   +1.12%
# 202                              Kin  $0.00009291   +7.39%
# 203                   Haven Protocol        $9.88  +22.91%
# 204                        DerivaDAO        $6.95   -2.69%
# 205                      Travala.com        $2.63   +4.37%
# 206                      LTO Network    $0.484887  +26.87%
# 207                        CyberVein    $0.124198   -0.06%
# 208                     Loom Network    $0.135808   +6.81%
# 209                     Neutrino USD        $1.01   +1.36%
# 210                            SKALE    $0.304537   +1.35%
# 211                         MonaCoin        $1.93   +2.07%
# 212                          Syscoin    $0.207583   +7.43%
# 213                         Litentry        $9.44  +14.06%
# 214                             Divi   $0.0559142  +12.62%
# 215               Injective Protocol       $12.18   +4.02%
# 216                    Gemini Dollar    $0.996321   -0.08%
# 217                             WINk  $0.00021461   +3.02%
# 218                            WHALE       $31.19   -5.05%
# 219                            Bytom   $0.0832667   +6.15%
# 220                      Shabu Shabu        $4.01  +29.90%
# 221                              Gas       $11.21   -0.73%
# 222                              c0x   $0.0281857   +1.59%
# 223                         ReddCoin  $0.00414796   +8.52%
# 224                       Creditcoin        $5.71   +0.30%
# 225                         Syntropy    $0.418469   +4.96%
# 226                         Counos X       $92.70   +0.13%
# 227                           Hathor     $0.82909  +13.90%
# 228                          JulSwap    $0.320474  +10.33%
# 229                        WhiteCoin        $2.16  -12.64%
# 230                     Mask Network       $16.53   -8.79%
# 231                    Axie Infinity        $2.69  +10.87%
# 232                         INO COIN        $6.30   +7.15%
# 233                        Aave USDC           $1   -0.20%
# 234                        ThoreCoin    $9,917.98   +6.62%
# 235                     BitMax Token    $0.753159   +6.44%
# 236                     Keep Network    $0.395514   +0.71%
# 237                   XinFin Network   $0.0379253   +6.65%
# 238            Rari Governance Token       $16.81   +1.37%
# 239                        Venus BNB        $4.78   +6.40%
# 240                        KeeperDAO      $417.84   +1.50%
# 241                        CoinMetro    $0.447047   -2.59%
# 242                             sBTC   $51,350.00   +6.65%
# 243                             NFTX      $319.07   -5.56%
# 244                         Tokenlon        $6.10   -0.50%
# 245                           Audius    $0.871153   -9.55%
# 246                              GNY        $1.26   +5.62%
# 247                              Vai    $0.898555   -1.67%
# 248                         botXcoin    $0.145913   +0.63%
# 249                  DeFiPulse Index      $457.15   +6.44%
# 250                        Sologenic        $1.10   -5.10%
# 251                      Tether Gold    $1,718.47   +0.17%
# 252                         PAX Gold    $1,727.63   +0.51%
# 253                        SuperFarm        $1.24   -0.58%
# 254                      Electroneum   $0.0114118   +3.45%
# 255                             Hive    $0.327873  +12.22%
# 256               Perpetual Protocol        $5.47   -6.48%
# 257                      RedFOX Labs    $0.139309   +1.04%
# 258                         Edgeware   $0.0197112   +0.70%
# 259                  Origin Protocol    $0.569994  +25.31%
# 260                          e-Radix    $0.158921   +0.80%
# 261                           PARSIQ        $1.13   +1.98%
# 262                  Harvest Finance      $238.89   -6.09%
# 263                        Akropolis   $0.0408058  +11.00%
# 264                             API3        $4.92   +4.63%
# 265                          Elitium        $5.21   +2.59%
# 266                     Doctors Coin    $0.659381   +2.36%
# 267                        TitanSwap        $1.04   +0.22%
# 268                 Wootrade Network    $0.282462   +0.56%
# 269                        Handshake    $0.283108   -1.55%
# 270                          Efforce        $1.68   -0.04%
# 271                             sUSD        $1.01   +0.03%
# 272          StakeHound Staked Ether    $1,596.64   +5.38%
# 273                          Raydium        $7.48  +16.80%
# 274                        Prometeus       $13.83   -0.94%
# 275             Sora Validator Token        $2.93   +1.77%
# 276                      DuckDaoDime       $96.17   +6.73%
# 277                       GreenPower   $0.0383849   -0.68%
# 278                           Linear    $0.074102   -1.32%
# 279                       xDAI Stake       $23.41  +16.68%
# 280                          Rarible       $30.75   +3.84%
# 281                    Hellenic Coin        $1.71   +4.61%
# 282                         MX Token     $0.77801  +21.52%
# 283                             cBAT   $0.0146004   +7.99%
# 284                    Phala Network      $0.6224   -0.28%
# 285                      Rocket Pool       $11.26  +13.04%
# 286                            Hegic     $0.25235   -2.18%
# 287                           RChain    $0.235259   -2.42%
# 288                         Chimpion        $3.40   +3.03%
# 289                     DUSK Network    $0.250981   +7.32%
# 290                          IRISnet    $0.111589   +5.12%
# 291                     LBRY Credits    $0.204886  +17.73%
# 292                           TrueFi    $0.377898  +18.09%
# 293               Unifi Protocol DAO       $35.69   +6.26%
# 294                       XeniosCoin        $1.34   +1.81%
# 295                            Atari    $0.228088   +4.58%
# 296                       Uquid Coin       $10.16   +6.66%
# 297                       QuarkChain   $0.0157431   +0.97%
# 298                          Swingby    $0.730528   +0.99%
# 299                           ChainX        $9.12   -7.52%
# 300                         Livepeer        $4.71  +22.01%
# 301                 Huobi Pool Token    $0.017584   -1.87%
# 302                        DFI.money    $2,144.59   +6.03%
# 303                       ShareToken    $0.035338   +1.93%
# 304                             Frax    $0.996108   -1.20%
# 305                            BSCEX       $22.24  +41.78%
# 306                     AdEx Network    $0.827218   +1.41%
# 307                      Wrapped NXM       $49.82   +7.84%
# 308                    Goose Finance      $108.20  +23.86%
# 309                     Bounce [old]    $2,770.83   -0.50%
# 310                           Energi        $2.37  +17.82%
# 311                             JUST    $0.056686   +3.13%
# 312                            Cream      $126.22   +0.36%
# 313                       SparkPoint   $0.0115581   +0.85%
# 314                            Nexus        $1.30   +2.59%
# 315                       BarnBridge       $59.10   -2.13%
# 316                    AllianceBlock     $0.62896   +2.20%
# 317                          Massnet    $0.953571   +0.84%
# 318                THORChain (ERC20)        $5.66   +0.57%
# 319                           StormX    $0.010815   +3.60%
# 320                 Morpheus.Network        $1.90  +17.98%
# 321                             tBTC   $51,254.00   +5.62%
# 322                  Tokamak Network        $6.45   +3.42%
# 323                            Mixin      $164.27   +5.13%
# 324                           CertiK        $2.13  +21.57%
# 325                            Metal        $1.33   +1.02%
# 326                        YIELD App    $0.802225  +28.76%
# 327                           Beldex   $0.0863452   +2.92%
# 328                              MVL  $0.00722151   +1.46%
# 329              Zero Collateral Dai   $0.0018846    0.00%
# 330                       Everipedia  $0.00849712   +2.60%
# 331                             MAPS    $0.981865   +4.78%
# 332                           WazirX    $0.292954   +2.31%
# 333                          Request     $0.08346   +4.84%
# 334                     dForce Token    $0.338204   -3.20%
# 335                           Cashaa     $0.12096   +3.47%
# 336                    HARD Protocol        $1.40   +2.98%
# 337                             Aion    $0.168983   +3.66%
# 338                       MANTRA DAO     $0.26198   +0.49%
# 339                    Nest Protocol   $0.0361097   +3.58%
# 340                          Streamr   $0.0969826   -0.91%
# 341                    Beefy.Finance      $926.46   +2.57%
# 342                             PIVX        $1.24   -1.97%
# 343                         Bytecoin  $0.00043033   +3.15%
# 344                   Ferrum Network    $0.597796   -3.81%
# 345                       ShareToken   $0.0354148   +1.83%
# 346                           Bondly    $0.473701   +9.30%
# 347                           Tellor       $40.21   +8.22%
# 348                         pNetwork        $1.86  +27.30%
# 349                          Cartesi    $0.241003   +8.28%
# 350                        DAO Maker        $3.61   +1.26%
# 351                             Ergo        $2.59  +18.35%
# 352                  UniLend Finance        $2.63   +1.41%
# 353                             Orbs   $0.0344051   +2.02%
# 354                          ankrETH    $1,584.77   +7.15%
# 355                        Aeternity    $0.229368  +69.00%
# 356                     bZx Protocol    $0.462033   +3.28%
# 357                         BOSAGORA    $0.215309   +2.41%
# 358                       Centrality    $0.060999   -8.12%
# 359                            Vitae        $3.80   +4.00%
# 360                    Thunder Token   $0.0108734   +3.58%
# 361                           Marlin    $0.149746   +4.68%
# 362                        Aave TUSD           $1    0.00%
# 363                      Waltonchain        $1.02   +2.43%
# 364                              DIA        $2.50   +7.51%
# 365                      Einsteinium    $0.333111   +6.86%
# 366                      Bao Finance  $0.00131775   +4.10%
# 367                             Firo        $6.33   +1.27%
# 368    Darwinia Network Native Token    $0.140302   +3.33%
# 369                            Ignis   $0.0964378   +1.01%
# 370                   DLP Duck Token        $1.91   +0.93%
# 371                           Enzyme       $40.23   -1.35%
# 372                     Tornado Cash      $184.02   +0.11%
# 373                   Bella Protocol        $2.75   -3.86%
# 374                         SmartKey     $0.32512   +2.49%
# 375                 UnFederalReserve    $0.210792   +1.50%
# 376                       Aavegotchi        $1.43   -3.57%
# 377                             Hxro    $0.313798   +1.81%
# 378                         Keep3rV1      $283.70   +0.37%
# 379                         Bluzelle    $0.256996  +19.27%
# 380                         Frontier        $2.25   -5.39%
# 381                            Qcash    $0.152205   +0.25%
# 382                Unit Protocol New    $0.298414   -5.01%
# 383                    Bridge Mutual        $2.48   -8.06%
# 384                            Velas   $0.0426885   +3.01%
# 385                      KardiaChain   $0.0273974   +4.73%
# 386                       WaykiChain    $0.326484   -0.77%
# 387                            SOLVE    $0.181944   +0.99%
# 388           Spartan Protocol Token    $0.911113   +3.64%
# 389                              Zap    $0.288882  +10.70%
# 390                             MORK        $9.36   +8.61%
# 391                        Spendcoin   $0.0261274   -0.13%
# 392                         DexTools    $0.596849   +3.14%
# 393                    JustLiquidity      $197.28   +6.60%
# 394                        Venus ETH       $33.34   +7.28%
# 395                       Verus Coin    $0.924394   +8.17%
# 396                Sport and Leisure   $0.0989243  +11.75%
# 397                             yUSD        $1.26   -0.72%
# 398                    DxChain Token  $0.00133919   +0.70%
# 399                       Frax Share        $7.30  +10.91%
# 400                           Minter   $0.0155424   +2.73%
# 401                     BTU Protocol    $0.710921   +7.25%
# 402                    Zero Exchange    $0.227824   -8.31%
# 403                     Pirate Chain    $0.352696   +9.72%
# 404                          Everest    $0.456596   -2.21%
# 405                    Nash Exchange        $2.14  +53.41%
# 406               Etherisc DIP Token    $0.291142  +14.35%
# 407                  USDP Stablecoin        $1.04   +6.26%
# 408                           Bounce       $24.87   +3.00%
# 409                             USDX    $0.793696   -4.06%
# 410                      APY.Finance        $2.45   +6.48%
# 411                             Meta        $2.52  +15.61%
# 412                          HydraDX    $0.115738    0.00%
# 413                 Spartan Protocol    $0.932987   +3.19%
# 414                             Meme    $1,978.77   +0.94%
# 415                             NULS    $0.587773   +8.60%
# 416                        BoringDAO      $609.80   +0.16%
# 417                      Groestlcoin    $0.756221   +3.69%
# 418                      Shopping.io       $51.39  +27.62%
# 419                         Flamingo    $0.383818   +7.34%
# 420              Terra Virtua Kolect    $0.561455   +9.50%
# 421                      STASIS EURO        $1.20   +0.77%
# 422                             DIGG   $27,891.00   -4.12%
# 423                          Elastos        $3.27  +17.84%
# 424                            Nimiq  $0.00764954   +0.59%
# 425                      mStable USD        $1.01   -0.20%
# 426                        VerusCoin      $0.9201   +9.37%
# 427                           Cherry        $9.52   +6.92%
# 428                            Carry  $0.00771414   +3.02%
# 429                        Quickswap      $291.57   -1.29%
# 430                             DeXe       $16.56  +57.38%
# 431                 Empty Set Dollar     $0.10048  -17.36%
# 432                   Minter Network   $0.0154207   +2.81%
# 433                          Anyswap        $2.68   +5.32%
# 434                     Render Token    $0.324773  +14.58%
# 435                       Venus BUSD   $0.0203205   +0.04%
# 436            Friends With Benefits       $26.20   +8.08%
# 437                   cVault.finance    $4,578.60   +5.97%
# 438                           Lambda   $0.0387513   +4.49%
# 439                          Everest    $0.453859   -1.48%
# 440                         TerraKRW  $0.00089806   +1.53%
# 441                         MediBloc    $0.018838   +7.02%
# 442                             REVV    $0.203068  +22.10%
# 443                              MXC   $0.0200265   +7.72%
# 444                          Rootkit    $4,477.12   +1.69%
# 445                       Multiplier    $0.459267   -7.76%
# 446                            Opium        $7.88   +2.93%
# 447                            Zenon        $9.77   +7.38%
# 448                       ARPA Chain   $0.0442686   +3.28%
# 449                        Contentos   $0.0174206   +0.32%
# 450                             Beam    $0.604161   +6.53%
# 451       Neutrino System Base Token       $23.27   +0.20%
# 452                     FIO Protocol    $0.191765   +3.47%
# 453  UNION Protocol Governance Token    $0.068873  +13.62%
# 454                           Kadena    $0.389586   +4.57%
# 455                             Oxen    $0.934381   +4.14%
# 456                      Celo Dollar           $1   -0.12%
# 457                           Cortex    $0.196383   +3.69%
# 458                  Oraichain Token       $45.79   -0.00%
# 459                             IDEX    $0.070978   +1.32%
# 460                          Bonfida        $1.55  +15.08%
# 461                    Crust Network       $20.25   +8.90%
# 462                   Shroom.Finance    $0.793692  +28.64%
# 463                      Dragonchain     $0.12962   +4.05%
# 464                           EasyFi       $24.57   +4.20%
# 465                        Phantasma    $0.486514  +18.86%
# 466                            Telos    $0.201192   -4.53%
# 467                        v.systems   $0.0212698   +4.05%
# 468                          Skycoin        $2.34   -5.47%
# 469                        COCOS BCX    $0.924438   +3.47%
# 470                            Axion  $0.00040401  +12.84%
# 471                       BitZ Token    $0.369264   +0.83%
# 472                 Umbrella Network        $1.26   -1.79%
# 473   Standard Tokenization Protocol   $0.0450238   +5.70%
# 474                              YAM        $3.21   +1.00%
# 475                         Switcheo   $0.0339825   -0.80%
# 476                      inSure DeFi  $0.00318102  -12.94%
# 477                      Cream ETH 2    $1,485.75   +7.97%
# 478                        Karma DAO        $7.82   +5.15%
# 479                            88mph      $123.17  +24.82%
# 480                         Metadium   $0.0357861  +16.70%
# 481                  Decentral Games      $221.05   +6.16%
# 482                Sentinel Protocol   $0.0965552  +13.16%
# 483                     Dego Finance        $6.61   +9.27%
# 484                      DigitalBits   $0.0466976  +27.50%
# 485                            Aergo    $0.162876   +5.20%
# 486                           SportX    $0.441271   +1.76%
# 487                     PAID Network    $0.352458  +22.10%
# 488                             Auto    $2,606.26   +0.08%
# 489                        HyperCash    $0.952582   +5.41%
# 490             The Midas Touch Gold  $0.00553697   +3.89%
# 491                         Unisocks  $111,300.00  +19.07%
# 492                        MobieCoin    $0.020553   +8.22%
# 493                          Navcoin     $0.59264  +33.88%
# 494                         Aave DAI        $1.01    0.00%
# 495                             DREP   $0.0104248   +6.49%
# 496                   Vesper Finance       $24.21  -11.49%
# 497                   Hermez Network        $5.58   +8.33%
# 498                           Gather    $0.449652   +0.27%
# 499                      Chain Games    $0.115142   +7.55%
# 500                         Alchemix    $1,046.72  -17.47%

# %%
def
